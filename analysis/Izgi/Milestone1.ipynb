# %% [markdown]
# #TASK 1
# #I have accepted the project through the link provided on the Milestone 1 page.
# #I cloned the repository to my computer.
# #I renamed the file "person2" to "izgi" using the "mv" command.

# %%
#TASK 2
#During our first meeting, we have discussed that how we are interested in ways one can protect themselves from COVID-19.(other than the vaccine)
#When we came across a dataset that consisted of different food groups and COVID-19, we have decided to choose the dataset for our project.
#Yuen Yee created the Ed discussion posts for Group and Project approval

# %%
#TASK 3
#During our second meeting, we have provided the answers to the questions to introduce our data and what we plan to do with it in terms of analysis.

# %%
#TASK 4
#Uploading the data through coding

# %%
import pandas as pd
pd.read_csv("/Users/izgikocacelebi/Downloads/Fat_Supply_Quantity_Data.csv")
pd.read_csv("/Users/izgikocacelebi/Downloads/Food_Supply_kcal_Data.csv")
pd.read_csv("/Users/izgikocacelebi/Downloads/Food_Supply_Quantity_kg_Data.csv")
pd.read_csv("/Users/izgikocacelebi/Downloads/Protein_Supply_Quantity_Data.csv")
pd.read_csv("/Users/izgikocacelebi/Downloads/Supply_Food_Data_Descriptions.csv")
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...
