# %% [markdown]
# # TASK 1

# %% [markdown]
# Research Question : The effects of protein and fat intake percentage from animal products on COVID-19 death cases.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Import Dataset
# The related dataset is imported.

# %%
proteinSupply = pd.read_csv('/Users/izgikocacelebi/Downloads/Protein_Supply_Quantity_Data.csv')
proteinSupply
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
fatSupply = pd.read_csv("/Users/izgikocacelebi/Downloads/Fat_Supply_Quantity_Data.csv")
fatSupply
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
food_descriptions = pd.read_csv("/Users/izgikocacelebi/Downloads/Supply_Food_Data_Descriptions.csv")

# %%
food_descriptions
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...

# %% [markdown]
# 2. Data Cleaning

# %%
proteinSupply = proteinSupply[['Country','Animal Products','Deaths']]
proteinSupply
# Out:
#                                 Country  Animal Products    Deaths
# 0                           Afghanistan           9.7523  0.006186
# 1                               Albania          27.7469  0.050951
# 2                               Algeria          13.8360  0.006558
# 3                                Angola          15.2311  0.001461
# 4                   Antigua and Barbuda          33.1901  0.007143
# ..                                  ...              ...       ...
# 165  Venezuela (Bolivarian Republic of)          22.5411  0.004287
# 166                             Vietnam          20.4466  0.000036
# 167                               Yemen          10.0122  0.002062
# 168                              Zambia           9.8925  0.004564
# 169                            Zimbabwe          11.3443  0.008854
#
# [170 rows x 3 columns]

# %%
fatSupply = fatSupply[['Country','Animal Products','Deaths']]
fatSupply
# Out:
#                                 Country  Animal Products    Deaths
# 0                           Afghanistan          21.6397  0.006186
# 1                               Albania          32.0002  0.050951
# 2                               Algeria          14.4175  0.006558
# 3                                Angola          15.3041  0.001461
# 4                   Antigua and Barbuda          27.7033  0.007143
# ..                                  ...              ...       ...
# 165  Venezuela (Bolivarian Republic of)          16.3261  0.004287
# 166                             Vietnam          33.2484  0.000036
# 167                               Yemen          12.5401  0.002062
# 168                              Zambia           9.6005  0.004564
# 169                            Zimbabwe          10.3796  0.008854
#
# [170 rows x 3 columns]

# %%
proteinSupply_cleaned = proteinSupply.rename(columns = {
    'Animal Products' : '% Protein in Animal Products',
    'Deaths':'% COVID-19 Deaths'
} )
proteinSupply_cleaned
# Out:
#                                 Country  % Protein in Animal Products  \
# 0                           Afghanistan                        9.7523
# 1                               Albania                       27.7469
# 2                               Algeria                       13.8360
# 3                                Angola                       15.2311
# 4                   Antigua and Barbuda                       33.1901
# ..                                  ...                           ...
# 165  Venezuela (Bolivarian Republic of)                       22.5411
# 166                             Vietnam                       20.4466
# 167                               Yemen                       10.0122
# 168                              Zambia                        9.8925
# 169                            Zimbabwe                       11.3443
#
#      % COVID-19 Deaths
# 0             0.006186
# 1             0.050951
# 2             0.006558
# 3             0.001461
# ...

# %%
fatSupply_cleaned = fatSupply.rename(columns = {
    'Animal Products' : '%Fat in Animal Products',
    'Deaths':'% COVID-19 Deaths'
} )
fatSupply_cleaned
# Out:
#                                 Country  %Fat in Animal Products  \
# 0                           Afghanistan                  21.6397
# 1                               Albania                  32.0002
# 2                               Algeria                  14.4175
# 3                                Angola                  15.3041
# 4                   Antigua and Barbuda                  27.7033
# ..                                  ...                      ...
# 165  Venezuela (Bolivarian Republic of)                  16.3261
# 166                             Vietnam                  33.2484
# 167                               Yemen                  12.5401
# 168                              Zambia                   9.6005
# 169                            Zimbabwe                  10.3796
#
#      % COVID-19 Deaths
# 0             0.006186
# 1             0.050951
# 2             0.006558
# 3             0.001461
# 4             0.007143
# ..                 ...
# ...

# %%
print(proteinSupply_cleaned.count(axis = 'rows') )
# Out:
# Country                         170
# % Protein in Animal Products    170
# % COVID-19 Deaths               164
# dtype: int64

# %%
print(fatSupply_cleaned.count(axis = 'rows'))
# Out:
# Country                    170
# %Fat in Animal Products    170
# % COVID-19 Deaths          164
# dtype: int64

# %% [markdown]
# It can be seen that there are 6 rows with missing values in COVID-19 Deaths column.

# %% [markdown]
# - Dealing with missing values

# %%
proteinSupply_cleaned = proteinSupply_cleaned.dropna().reset_index()
fatSupply_cleaned = fatSupply_cleaned.dropna().reset_index()

# %%
proteinSupply_cleaned
# Out:
#      index                             Country  % Protein in Animal Products  \
# 0        0                         Afghanistan                        9.7523
# 1        1                             Albania                       27.7469
# 2        2                             Algeria                       13.8360
# 3        3                              Angola                       15.2311
# 4        4                 Antigua and Barbuda                       33.1901
# ..     ...                                 ...                           ...
# 159    165  Venezuela (Bolivarian Republic of)                       22.5411
# 160    166                             Vietnam                       20.4466
# 161    167                               Yemen                       10.0122
# 162    168                              Zambia                        9.8925
# 163    169                            Zimbabwe                       11.3443
#
#      % COVID-19 Deaths
# ...

# %%
fatSupply_cleaned
# Out:
#      index                             Country  %Fat in Animal Products  \
# 0        0                         Afghanistan                  21.6397
# 1        1                             Albania                  32.0002
# 2        2                             Algeria                  14.4175
# 3        3                              Angola                  15.3041
# 4        4                 Antigua and Barbuda                  27.7033
# ..     ...                                 ...                      ...
# 159    165  Venezuela (Bolivarian Republic of)                  16.3261
# 160    166                             Vietnam                  33.2484
# 161    167                               Yemen                  12.5401
# 162    168                              Zambia                   9.6005
# 163    169                            Zimbabwe                  10.3796
#
#      % COVID-19 Deaths
# 0             0.006186
# 1             0.050951
# 2             0.006558
# ...

# %%
proteinSupply_cleaned = proteinSupply_cleaned.drop(['index'],axis =1)
fatSupply_cleaned = fatSupply_cleaned.drop(['index'],axis=1)

# %%
proteinSupply_cleaned
# Out:
#                                 Country  % Protein in Animal Products  \
# 0                           Afghanistan                        9.7523
# 1                               Albania                       27.7469
# 2                               Algeria                       13.8360
# 3                                Angola                       15.2311
# 4                   Antigua and Barbuda                       33.1901
# ..                                  ...                           ...
# 159  Venezuela (Bolivarian Republic of)                       22.5411
# 160                             Vietnam                       20.4466
# 161                               Yemen                       10.0122
# 162                              Zambia                        9.8925
# 163                            Zimbabwe                       11.3443
#
#      % COVID-19 Deaths
# 0             0.006186
# 1             0.050951
# 2             0.006558
# 3             0.001461
# ...

# %%
fatSupply_cleaned
# Out:
#                                 Country  %Fat in Animal Products  \
# 0                           Afghanistan                  21.6397
# 1                               Albania                  32.0002
# 2                               Algeria                  14.4175
# 3                                Angola                  15.3041
# 4                   Antigua and Barbuda                  27.7033
# ..                                  ...                      ...
# 159  Venezuela (Bolivarian Republic of)                  16.3261
# 160                             Vietnam                  33.2484
# 161                               Yemen                  12.5401
# 162                              Zambia                   9.6005
# 163                            Zimbabwe                  10.3796
#
#      % COVID-19 Deaths
# 0             0.006186
# 1             0.050951
# 2             0.006558
# 3             0.001461
# 4             0.007143
# ..                 ...
# ...

# %% [markdown]
#  3. Data Processsing

# %%
fat = pd.DataFrame(fatSupply_cleaned['%Fat in Animal Products'])
fat
# Out:
#      %Fat in Animal Products
# 0                    21.6397
# 1                    32.0002
# 2                    14.4175
# 3                    15.3041
# 4                    27.7033
# ..                       ...
# 159                  16.3261
# 160                  33.2484
# 161                  12.5401
# 162                   9.6005
# 163                  10.3796
#
# [164 rows x 1 columns]

# %%
animalProd = pd.concat([proteinSupply_cleaned,fat], axis = 1)
animalProd
# Out:
#                                 Country  % Protein in Animal Products  \
# 0                           Afghanistan                        9.7523
# 1                               Albania                       27.7469
# 2                               Algeria                       13.8360
# 3                                Angola                       15.2311
# 4                   Antigua and Barbuda                       33.1901
# ..                                  ...                           ...
# 159  Venezuela (Bolivarian Republic of)                       22.5411
# 160                             Vietnam                       20.4466
# 161                               Yemen                       10.0122
# 162                              Zambia                        9.8925
# 163                            Zimbabwe                       11.3443
#
#      % COVID-19 Deaths  %Fat in Animal Products
# 0             0.006186                  21.6397
# ...

# %%
animalProd = animalProd.reindex(columns = ['Country','% Protein in Animal Products', '%Fat in Animal Products', '% COVID-19 Deaths'])

# %%
animalProd.dropna()
# Out:
#                                 Country  % Protein in Animal Products  \
# 0                           Afghanistan                        9.7523
# 1                               Albania                       27.7469
# 2                               Algeria                       13.8360
# 3                                Angola                       15.2311
# 4                   Antigua and Barbuda                       33.1901
# ..                                  ...                           ...
# 159  Venezuela (Bolivarian Republic of)                       22.5411
# 160                             Vietnam                       20.4466
# 161                               Yemen                       10.0122
# 162                              Zambia                        9.8925
# 163                            Zimbabwe                       11.3443
#
#      %Fat in Animal Products  % COVID-19 Deaths
# 0                    21.6397           0.006186
# ...

# %%
animalProd.to_csv("izgi_analysis.csv")

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Method Chaining

# %%
def load_and_process(fat_path, protein_path) :
    
    df1 = pd.read_csv(fat_path)[['Country','Animal Products','Deaths']].rename(columns = {
    'Animal Products' : '%Fat in Animal Products',
    'Deaths':'% COVID-19 Deaths'
    }).dropna().reset_index().drop(['index', 'Country','% COVID-19 Deaths'],axis =1)
    
    
    df2 = pd.read_csv(protein_path)[['Country','Animal Products','Deaths']].rename(columns = {
    'Animal Products' : '% Protein in Animal Products',
    'Deaths':'% COVID-19 Deaths'
    }).dropna().reset_index().drop(['index'], axis =1)
    
    df3 = pd.concat([df2,df1],axis =1).reindex(columns = ['Country','% Protein in Animal Products', '%Fat in Animal Products', '% COVID-19 Deaths'])
    return df3

load_and_process("/Users/izgikocacelebi/Downloads/Fat_Supply_Quantity_Data.csv",'/Users/izgikocacelebi/Downloads/Protein_Supply_Quantity_Data.csv')
# Out:
#                                 Country  % Protein in Animal Products  \
# 0                           Afghanistan                        9.7523
# 1                               Albania                       27.7469
# 2                               Algeria                       13.8360
# 3                                Angola                       15.2311
# 4                   Antigua and Barbuda                       33.1901
# ..                                  ...                           ...
# 159  Venezuela (Bolivarian Republic of)                       22.5411
# 160                             Vietnam                       20.4466
# 161                               Yemen                       10.0122
# 162                              Zambia                        9.8925
# 163                            Zimbabwe                       11.3443
#
#      %Fat in Animal Products  % COVID-19 Deaths
# 0                    21.6397           0.006186
# ...

# %%
from scripts import project_function as pt
df4 = pt.load_and_process("/Users/izgikocacelebi/Downloads/Fat_Supply_Quantity_Data.csv",'/Users/izgikocacelebi/Downloads/Protein_Supply_Quantity_Data.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-0fcbdb20f208> in <module>
# ----> 1 from scripts import project_function as pt
#       2 df4 = pt.load_and_process("/Users/izgikocacelebi/Downloads/Fat_Supply_Quantity_Data.csv",'/Users/izgikocacelebi/Downloads/Protein_Supply_Quantity_Data.csv')
#
# ImportError: cannot import name 'project_function' from 'scripts' (unknown location)

# %% [markdown]
# # Task 3 :EDA

# %%
animalProd.describe(exclude = np.object).T
# Out:
# <ipython-input-28-78034b2e3c7d>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   animalProd.describe(exclude = np.object).T
#                               count       mean       std     min        25%  \
# % Protein in Animal Products  164.0  21.138788  7.932568  4.4561  14.385450
# %Fat in Animal Products       164.0  20.671132  8.003350  5.0182  14.907200
# % COVID-19 Deaths             164.0   0.039370  0.048718  0.0000   0.002013
#
#                                     50%        75%        max
# % Protein in Animal Products  21.772550  28.243200  35.786000
# %Fat in Animal Products       20.866900  26.913750  36.901800
# % COVID-19 Deaths              0.011998   0.069503   0.185428

# %%
from pandas_profiling import ProfileReport

# %%
profile = pandas_profiling.ProfileReport(animalProd)
display(profile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a7e8868ce557> in <module>
# ----> 1 profile = pandas_profiling.ProfileReport(animalProd)
#       2 display(profile)
#
# NameError: name 'pandas_profiling' is not defined

# %%
## Visualizations

# %%
p1_protein = sns.scatterplot(data = animalProd, x ='% Protein in Animal Products', y= "% COVID-19 Deaths")
p2_fat = sns.scatterplot(data = animalProd, x ='%Fat in Animal Products', y="% COVID-19 Deaths", marker = 'x')
plt.legend(["% Protein in Animal Products","% Fat in Animal Products"],bbox_to_anchor = (1.4,1))
p1_protein.set(title = "The relationship between Protein and Fat Consumed from Animal Products and COVID-19 Deaths")
# Out:
# /Users/izgikocacelebi/opt/miniconda3/lib/python3.8/site-packages/seaborn/relational.py:651: UserWarning: You passed a edgecolor/edgecolors ('w') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(*args, **kws)
# [Text(0.5, 1.0, 'The relationship between Protein and Fat Consumed from Animal Products and COVID-19 Deaths')]
