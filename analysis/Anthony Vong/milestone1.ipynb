# %%
#Milestone 1
## Task 1: Project Setup
### One member (Izgi) accepted the group repository link on canvas to create our group's repository.
### Other members found the repository and clicked the link to join
### Repository was cloned into local directory using "git clone" to start work

# %%
## Task 2: Choosing a topic & dataset approval
### A description of the dataset was posted onto Ed Discussion for approval.
### Our data set: COVID-19 Healthy Diet (approved)

# %%
## Task 3: Introduce & Describe dataset
### The group met up virtually to create a writeup description of the dataset and research question.

# %%
## Task 4: Load dataset from file or URL

#Food supply (kcal) data
import pandas as pd
pd.read_csv("C:/Users/vong2/OneDrive/Desktop/data301/project-group28-project/data/raw/Food_Supply_kcal_Data.csv")
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           4.7774
# 1                               Albania               0.9120          16.0930
# 2                               Algeria               0.0896           6.0326
# 3                                Angola               1.9388           4.6927
# 4                   Antigua and Barbuda               2.3041          15.3672
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.8454           7.2303
# 166                             Vietnam               0.7150          10.9806
# 167                               Yemen               0.0000           3.4667
# 168                              Zambia               1.1925           3.3043
# 169                            Zimbabwe               1.4269           3.9356
#
# ...

# %%
#Food supply quantity (kg) data
import pandas as pd
pd.read_csv("C:/Users/vong2/OneDrive/Desktop/data301/project-group28-project/data/raw/Food_Supply_Quantity_kg_Data.csv")
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
#Protein supply quantity data
import pandas as pd
pd.read_csv("C:/Users/vong2/OneDrive/Desktop/data301/project-group28-project/data/raw/Protein_Supply_Quantity_Data.csv")
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           9.7523
# 1                               Albania               0.1840          27.7469
# 2                               Algeria               0.0323          13.8360
# 3                                Angola               0.6285          15.2311
# 4                   Antigua and Barbuda               0.1535          33.1901
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.1955          22.5411
# 166                             Vietnam               0.1555          20.4466
# 167                               Yemen               0.0000          10.0122
# 168                              Zambia               0.4824           9.8925
# 169                            Zimbabwe               0.2929          11.3443
#
# ...

# %%
#Fat supply quantity data
import pandas as pd
pd.read_csv("C:/Users/vong2/OneDrive/Desktop/data301/project-group28-project/data/raw/Fat_Supply_Quantity_Data.csv")
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000          21.6397
# 1                               Albania               0.0000          32.0002
# 2                               Algeria               0.0000          14.4175
# 3                                Angola               0.0000          15.3041
# 4                   Antigua and Barbuda               0.0000          27.7033
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.0000          16.3261
# 166                             Vietnam               0.0000          33.2484
# 167                               Yemen               0.0000          12.5401
# 168                              Zambia               0.0783           9.6005
# 169                            Zimbabwe               0.0000          10.3796
#
# ...

# %%
#Supply food data descriptions
import pandas as pd
pd.read_csv("C:/Users/vong2/OneDrive/Desktop/data301/project-group28-project/data/raw/Supply_Food_Data_Descriptions.csv")
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...
