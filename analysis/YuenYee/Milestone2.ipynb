# %% [markdown]
# # Milestone 2

# %% [markdown]
# ## Installation of Packages

# %%
# Importing dataset - Food Supply Quantity (kg)
import pandas as pd
foodsupplykg = pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_Quantity_kg_Data.csv')
foodsupplykcal = pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_kcal_Data.csv')

# %%
foodsupplykg
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
foodsupplykcal
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           4.7774
# 1                               Albania               0.9120          16.0930
# 2                               Algeria               0.0896           6.0326
# 3                                Angola               1.9388           4.6927
# 4                   Antigua and Barbuda               2.3041          15.3672
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.8454           7.2303
# 166                             Vietnam               0.7150          10.9806
# 167                               Yemen               0.0000           3.4667
# 168                              Zambia               1.1925           3.3043
# 169                            Zimbabwe               1.4269           3.9356
#
# ...

# %%
### Supply food data descriptions

pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Supply_Food_Data_Descriptions.csv')
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...

# %%
foodsupplykg_cleaned = food_supply[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']].rename(columns = {'Stimulants' : 'Stimulants (kg)'})
foodsupplykg_cleaned
# Out:
#                                 Country  Stimulants (kg)  Confirmed    Deaths  \
# 0                           Afghanistan           0.3078   0.142134  0.006186
# 1                               Albania           0.1055   2.967301  0.050951
# 2                               Algeria           0.2216   0.244897  0.006558
# 3                                Angola           0.0508   0.061687  0.001461
# 4                   Antigua and Barbuda           0.1564   0.293878  0.007143
# ..                                  ...              ...        ...       ...
# 165  Venezuela (Bolivarian Republic of)           0.1479   0.452585  0.004287
# 166                             Vietnam           0.2880   0.002063  0.000036
# 167                               Yemen           0.2199   0.007131  0.002062
# 168                              Zambia           0.0618   0.334133  0.004564
# 169                            Zimbabwe           0.1494   0.232033  0.008854
#
# ...

# %%
foodsupplykcal_cleaned = foodsupplykcal[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']].rename(columns = {'Stimulants' : 'Stimulants (kcal)'})
fskcal_cleaned = foodsupplykcal_cleaned[['Stimulants (kcal)']]
fskcal_cleaned
# Out:
#      Stimulants (kcal)
# 0               0.0750
# 1               0.2501
# 2               0.1493
# 3               0.0441
# 4               0.4937
# ..                 ...
# 165             0.0667
# 166             0.1021
# 167             0.1212
# 168             0.0248
# 169             0.0460
#
# [170 rows x 1 columns]

# %%
# There are some missing row values for confirmed, deaths, recovered, and active covid cases
print(foodsupplykg_cleaned.count(axis='rows'))
print(foodsupplykcal_cleaned.count(axis='rows'))
# Out:
# Country       170
# Stimulants    170
# Confirmed     164
# Deaths        164
# Recovered     164
# Active        162
# Population    170
# dtype: int64
# Country       170
# Stimulants    170
# Confirmed     164
# Deaths        164
# Recovered     164
# Active        162
# Population    170
# dtype: int64

# %%
# Double check interpretations of units. Is it meant to be converted to a percentage or is it already a percentage (a low one)
foodsupply = pd.concat([foodsupplykg_cleaned, fskcal_cleaned], axis = 1)
foodsupply_x100 = foodsupply.iloc[:,[1,2,3,4,5,7]].multiply(100)
foodsupply
# Out:
#                                 Country  Stimulants (kg)  Confirmed    Deaths  \
# 0                           Afghanistan           0.3078   0.142134  0.006186
# 1                               Albania           0.1055   2.967301  0.050951
# 2                               Algeria           0.2216   0.244897  0.006558
# 3                                Angola           0.0508   0.061687  0.001461
# 4                   Antigua and Barbuda           0.1564   0.293878  0.007143
# ..                                  ...              ...        ...       ...
# 165  Venezuela (Bolivarian Republic of)           0.1479   0.452585  0.004287
# 166                             Vietnam           0.2880   0.002063  0.000036
# 167                               Yemen           0.2199   0.007131  0.002062
# 168                              Zambia           0.0618   0.334133  0.004564
# 169                            Zimbabwe           0.1494   0.232033  0.008854
#
# ...

# %%
"""
Notes to self:

- Add a new column of population recovered based on percentage given in recovered and population of each country.
- Figure out a way to deal with missing values for covid related parameters.
- Think about how to best represent the data visually.

"""
