# %% [markdown]
# # Milestone 2

# %% [markdown]
# **Research Question:** Analyzing the relationship between stimulant supply and the percentage COVID-19 recoveries.

# %% [markdown]
# ## Installation of Packages

# %%
# Importing dataset - Food Supply Quantity (kg)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Data Analysis Pipeline

# %% [markdown]
# **1. Importing Data:**
# - Importing datasets Food Supply Quantity (kg) & Food Supply (kcal)

# %%
foodsupplykg = pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_Quantity_kg_Data.csv')
foodsupplykcal = pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_kcal_Data.csv')

# %%
foodsupplykg
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               2.5952       0.0403
# 166                             Vietnam               1.4591       0.1640
# 167                               Yemen               0.0364       0.0446
# 168                              Zambia               5.7360       0.0829
# 169                            Zimbabwe               4.0552       0.0755
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# ...

# %%
foodsupplykcal
# Out:
#                                 Country  Alcoholic Beverages  Animal Products  \
# 0                           Afghanistan               0.0000           4.7774
# 1                               Albania               0.9120          16.0930
# 2                               Algeria               0.0896           6.0326
# 3                                Angola               1.9388           4.6927
# 4                   Antigua and Barbuda               2.3041          15.3672
# ..                                  ...                  ...              ...
# 165  Venezuela (Bolivarian Republic of)               0.8454           7.2303
# 166                             Vietnam               0.7150          10.9806
# 167                               Yemen               0.0000           3.4667
# 168                              Zambia               1.1925           3.3043
# 169                            Zimbabwe               1.4269           3.9356
#
# ...

# %%
### Supply food data descriptions

pd.read_csv('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Supply_Food_Data_Descriptions.csv')
# Out:
#                   Categories  \
# 0        Alcoholic Beverages
# 1                Animal fats
# 2            Animal Products
# 3    Aquatic Products, Other
# 4   Cereals - Excluding Beer
# 5                       Eggs
# 6              Fish, Seafood
# 7    Fruits - Excluding Wine
# 8                       Meat
# 9    Milk - Excluding Butter
# 10             Miscellaneous
# 11                    Offals
# 12                  Oilcrops
# 13                    Pulses
# 14                    Spices
# 15             Starchy Roots
# 16                Stimulants
# 17        Sugar & Sweeteners
# 18               Sugar Crops
# 19                  Treenuts
# 20            Vegetable Oils
# 21                Vegetables
# 22          Vegetal Products
#
#                                                 Items
# 0   Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1   Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2   Aquatic Animals, Others; Aquatic Plants; Bovin...
# ...

# %% [markdown]
# **2. Data Cleaning:**
# - Extracting columns of interest for analysis and removing colums not needed.

# %%
foodsupplykg_cleaned = foodsupplykg[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']].rename(columns = {'Stimulants':'% Stimulants (kg)','Confirmed':'% Confirmed','Deaths':'% Deaths','Recovered':'% Recovered','Active':'% Active'})
foodsupplykg_cleaned
# Out:
#                                 Country  % Stimulants (kg)  % Confirmed  \
# 0                           Afghanistan             0.3078     0.142134
# 1                               Albania             0.1055     2.967301
# 2                               Algeria             0.2216     0.244897
# 3                                Angola             0.0508     0.061687
# 4                   Antigua and Barbuda             0.1564     0.293878
# ..                                  ...                ...          ...
# 165  Venezuela (Bolivarian Republic of)             0.1479     0.452585
# 166                             Vietnam             0.2880     0.002063
# 167                               Yemen             0.2199     0.007131
# 168                              Zambia             0.0618     0.334133
# 169                            Zimbabwe             0.1494     0.232033
#
#      % Deaths  % Recovered  % Active  Population
# 0    0.006186     0.123374  0.012574  38928000.0
# ...

# %%
foodsupplykcal_cleaned = foodsupplykcal[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']].rename(columns = {'Stimulants':'% Stimulants (kcal)','Confirmed':'% Confirmed','Deaths':'% Deaths','Recovered':'% Recovered','Active':'% Active'})
foodsupplykcal_cleaned
# Out:
#                                 Country  % Stimulants (kcal)  % Confirmed  \
# 0                           Afghanistan               0.0750     0.142134
# 1                               Albania               0.2501     2.967301
# 2                               Algeria               0.1493     0.244897
# 3                                Angola               0.0441     0.061687
# 4                   Antigua and Barbuda               0.4937     0.293878
# ..                                  ...                  ...          ...
# 165  Venezuela (Bolivarian Republic of)               0.0667     0.452585
# 166                             Vietnam               0.1021     0.002063
# 167                               Yemen               0.1212     0.007131
# 168                              Zambia               0.0248     0.334133
# 169                            Zimbabwe               0.0460     0.232033
#
#      % Deaths  % Recovered  % Active  Population
# ...

# %% [markdown]
# - Checking for missing values or NaN values

# %%
# There are some missing row values for confirmed, deaths, recovered, and active covid cases
print(foodsupplykg_cleaned.count(axis='rows'))
print(foodsupplykcal_cleaned.count(axis='rows'))
# Out:
# Country              170
# % Stimulants (kg)    170
# % Confirmed          164
# % Deaths             164
# % Recovered          164
# % Active             162
# Population           170
# dtype: int64
# Country                170
# % Stimulants (kcal)    170
# % Confirmed            164
# % Deaths               164
# % Recovered            164
# % Active               162
# Population             170
# dtype: int64

# %%
missing1 = foodsupplykg_cleaned.isnull().sum()
missing2 = foodsupplykcal_cleaned.isnull().sum()
print(missing1)
print(missing2)
# Out:
# Country              0
# % Stimulants (kg)    0
# % Confirmed          6
# % Deaths             6
# % Recovered          6
# % Active             8
# Population           0
# dtype: int64
# Country                0
# % Stimulants (kcal)    0
# % Confirmed            6
# % Deaths               6
# % Recovered            6
# % Active               8
# Population             0
# dtype: int64

# %% [markdown]
# **2.2 Data Cleaning: Dealing with Missing Values**
#
# - Removing missing values
#
# For both foodsupplykg and foodsupplykcal dataframes, there are 6 missing values from 'Confirmed','Deaths', and 'Recovered' as well as 8 from 'Active'. There this rows should be removed from the dataframe.

# %%
foodsupplykg_cleaned = foodsupplykg_cleaned.dropna().reset_index()
foodsupplykcal_cleaned = foodsupplykcal_cleaned.dropna().reset_index()
foodsupplykcal_cleaned
# Out:
#      index                             Country  % Stimulants (kcal)  \
# 0        0                         Afghanistan               0.0750
# 1        1                             Albania               0.2501
# 2        2                             Algeria               0.1493
# 3        3                              Angola               0.0441
# 4        4                 Antigua and Barbuda               0.4937
# ..     ...                                 ...                  ...
# 157    165  Venezuela (Bolivarian Republic of)               0.0667
# 158    166                             Vietnam               0.1021
# 159    167                               Yemen               0.1212
# 160    168                              Zambia               0.0248
# 161    169                            Zimbabwe               0.0460
#
#      % Confirmed  % Deaths  % Recovered  % Active  Population
# 0       0.142134  0.006186     0.123374  0.012574  38928000.0
# ...

# %%
foodsupplykg_cleaned = foodsupplykg_cleaned.drop(['index'], axis=1)
foodsupplykcal_cleaned = foodsupplykcal_cleaned.drop(['index'], axis=1)

# %%
foodsupplykcal_cleaned
# Out:
#                                 Country  % Stimulants (kcal)  % Confirmed  \
# 0                           Afghanistan               0.0750     0.142134
# 1                               Albania               0.2501     2.967301
# 2                               Algeria               0.1493     0.244897
# 3                                Angola               0.0441     0.061687
# 4                   Antigua and Barbuda               0.4937     0.293878
# ..                                  ...                  ...          ...
# 157  Venezuela (Bolivarian Republic of)               0.0667     0.452585
# 158                             Vietnam               0.1021     0.002063
# 159                               Yemen               0.1212     0.007131
# 160                              Zambia               0.0248     0.334133
# 161                            Zimbabwe               0.0460     0.232033
#
#      % Deaths  % Recovered  % Active  Population
# ...

# %% [markdown]
# **3. Data Processing:**

# %%
stim = pd.DataFrame(foodsupplykcal_cleaned['% Stimulants (kcal)'])
stim
# Out:
#      % Stimulants (kcal)
# 0                 0.0750
# 1                 0.2501
# 2                 0.1493
# 3                 0.0441
# 4                 0.4937
# ..                   ...
# 157               0.0667
# 158               0.1021
# 159               0.1212
# 160               0.0248
# 161               0.0460
#
# [162 rows x 1 columns]

# %%
foodsupply = pd.concat([foodsupplykg_cleaned, stim], axis=1)
foodsupply
# Out:
#                                 Country  % Stimulants (kg)  % Confirmed  \
# 0                           Afghanistan             0.3078     0.142134
# 1                               Albania             0.1055     2.967301
# 2                               Algeria             0.2216     0.244897
# 3                                Angola             0.0508     0.061687
# 4                   Antigua and Barbuda             0.1564     0.293878
# ..                                  ...                ...          ...
# 157  Venezuela (Bolivarian Republic of)             0.1479     0.452585
# 158                             Vietnam             0.2880     0.002063
# 159                               Yemen             0.2199     0.007131
# 160                              Zambia             0.0618     0.334133
# 161                            Zimbabwe             0.1494     0.232033
#
#      % Deaths  % Recovered  % Active  Population  % Stimulants (kcal)
# ...

# %%
foodsupply = foodsupply.reindex(columns=['Country','% Stimulants (kg)','% Stimulants (kcal)','% Confirmed','% Deaths','% Recovered','% Active','Population'])
foodsupply
# Out:
#                                 Country  % Stimulants (kg)  \
# 0                           Afghanistan             0.3078
# 1                               Albania             0.1055
# 2                               Algeria             0.2216
# 3                                Angola             0.0508
# 4                   Antigua and Barbuda             0.1564
# ..                                  ...                ...
# 157  Venezuela (Bolivarian Republic of)             0.1479
# 158                             Vietnam             0.2880
# 159                               Yemen             0.2199
# 160                              Zambia             0.0618
# 161                            Zimbabwe             0.1494
#
#      % Stimulants (kcal)  % Confirmed  % Deaths  % Recovered  % Active  \
# 0                 0.0750     0.142134  0.006186     0.123374  0.012574
# 1                 0.2501     2.967301  0.050951     1.792636  1.123714
# ...

# %% [markdown]
# ## Task 2: Method Chaining

# %% [markdown]
# Step 1: Testing method chains
#
# Through building the analysis pipeline and creating the function, the method chaining was tested to produced the desired result.
#
# Step 2: Wrapping method chain(s)

# %%
def load_and_process(path_kg, path_kcal):
    
    # Method Chain 1 for path_kg (Load data, select relevant columns, rename columns, drop missing values)
    
    df1 = (pd.read_csv(path_kg)[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']]
           .rename(columns = {'Stimulants':'% Stimulants (kg)','Confirmed':'% Confirmed','Deaths':'% Deaths','Recovered':'% Recovered','Active':'% Active'})
           .dropna()
           .reset_index()
           .drop(['index'],axis=1)
            
    )
                        
    
    # Method Chain 2 for path_kcal (Load data, drop missing values, rename column, drop columns to leave only 'Stimulants' in df
                              
    df2 = (pd.read_csv(path_kcal)[['Country','Stimulants','Confirmed','Deaths','Recovered','Active','Population']]
           .dropna()
           .reset_index()
           .rename(columns = {'Stimulants':'% Stimulants (kcal)'})
           .drop(['index','Country','Confirmed','Deaths','Recovered','Active','Population'],axis=1)
    
    )
    
    # Method Chain 3 (combine both dataframes and reorder columns)
    
    df3 = (pd.concat([df1,df2],axis=1)
           .reindex(columns=['Country','% Stimulants (kg)','% Stimulants (kcal)','% Confirmed','% Deaths','% Recovered','% Active','Population'])
          
    )
    
    return df3

load_and_process('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_Quantity_kg_Data.csv','C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_kcal_Data.csv')
# Out:
#                                 Country  % Stimulants (kg)  \
# 0                           Afghanistan             0.3078
# 1                               Albania             0.1055
# 2                               Algeria             0.2216
# 3                                Angola             0.0508
# 4                   Antigua and Barbuda             0.1564
# ..                                  ...                ...
# 157  Venezuela (Bolivarian Republic of)             0.1479
# 158                             Vietnam             0.2880
# 159                               Yemen             0.2199
# 160                              Zambia             0.0618
# 161                            Zimbabwe             0.1494
#
#      % Stimulants (kcal)  % Confirmed  % Deaths  % Recovered  % Active  \
# 0                 0.0750     0.142134  0.006186     0.123374  0.012574
# 1                 0.2501     2.967301  0.050951     1.792636  1.123714
# ...

# %% [markdown]
# Step 3: Move your function into a new .py file

# %%
from .. import project_functions
df = project_functions.load_and_process('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_Quantity_kg_Data.csv','C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_kcal_Data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20280/3085184796.py in <module>
# ----> 1 from .. import project_functions
#       2 df = project_functions.load_and_process('C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_Quantity_kg_Data.csv','C:\\Users\\lyuen\\OneDrive\\desktop\\Data301\\Project\\project-group28-project\\data\\raw\\Food_Supply_kcal_Data.csv')
#       3 df
#       4
#
# ImportError: attempted relative import with no known parent package

# %%
"""
Notes to self:

- Think about how to best represent the data visually.

"""
